# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp37-none-any.whl size=9675 sha256=0eaa49b983b5c9942a7250b49be8d4a29602db75a44b3cc7512ea051f4cdd3cc
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %%
import wget
import os 
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/Colab/agro
# Out:
# /content/drive/MyDrive/Colab/agro

# %%
data = pd.read_csv('./final_merger.csv')

# %%
# data.rename(columns = {'영화 제목' : '영화제목', '유튜브 제목' : 'YT제목', '주 내용 있음': '주 내용' }, inplace = True)
data['marked'] = np.where((data['주 내용1']== 1.0 ) | (data['부분적 내용1']== 1.0) |(data['내용 없음1']== 1.0) , True, False)

# %%
marked_data = data.loc[data['marked'] == True].copy()
marked_data
# Out:
#             영화 제목  ... marked
# 3     100인,인간을말하다  ...   True
# 4         101달마시안  ...   True
# 5             10분  ...   True
# 6             10분  ...   True
# 7             10분  ...   True
# ...           ...  ...    ...
# 5122       효자동이발사  ...   True
# 5123           후궁  ...   True
# 5124     후궁[제왕의첩]  ...   True
# 5148        히든피겨스  ...   True
# 5154          히트맨  ...   True
#
# [1986 rows x 27 columns]

# %%
thumbs = marked_data['썸네일']
len(thumbs)
# Out:
# 1986

# %%
failed = []
count = 0
for i in thumbs:
    try:
        thumbnail = wget.download(i)
        os.rename('./hqdefault.jpg', './images/'+ i[23:34] + '.jpg')
        count+=1
    except:
        failed.append(i)
print('done')
print('successful: ', count)
print('failed: ', len(failed))
# Out:
# done
# successful:  1890
# failed:  96

# %%
import glob
all_images = glob.glob("*.jpg")
print(len(all_images))
print(len(set(all_images)))
thumb_video_ids = [i[:11]for i in all_images]
thumb_video_ids
